# %%
import pandas as pd
import re
df = pd.read_csv('../preprocess/all_lib.csv')
df['nltk'] = False
df['spacy'] = False
df['gensim'] = False
df['stanford-nlp'] = False
df['scikit-learn'] = False
df['textblob'] = False
df['polyglot'] = False
df['opennlp'] = False
df['charniak-parser'] = False
df['pytextrank'] = False
df['huggingface-transformers'] = False
df['rasa-nlu'] = False
df['dialogflow-es'] = False
df['huggingface-tokenizers'] = False
df['johnsnowlabs-spark-nlp'] = False
df['flair'] = False
df['sense2vec'] = False
df['python-pattern'] = False

# %%
def issklearn(str):
    a = re.search(r'\b(scikit-learn)\b', str)
    if a is None:
        return False
    else:
        return True
def isnltk(str):
    a = re.search(r'\b(nltk)\b', str)
    if a is None:
        return False
    else:
        return True
def isspacy(str):
    a = re.search(r'\b(spacy)\b', str)
    if a is None:
        return False
    else:
        return True
def isgensim(str):
    a = re.search(r'\b(gensim)\b', str)
    if a is None:
        return False
    else:
        return True
def isstanfordnlp(str):
    a = re.search(r'\b(stanford-nlp)\b', str)
    if a is None:
        return False
    else:
        return True
def istextblob(str):
    a = re.search(r'\b(textblob)\b', str)
    if a is None:
        return False
    else:
        return True
def ispolyglot(str):
    a = re.search(r'\b(polyglot)\b', str)
    if a is None:
        return False
    else:
        return True
def isopennlp(str):
    a = re.search(r'\b(opennlp)\b', str)
    if a is None:
        return False
    else:
        return True
def ischarniakparser(str):
    a = re.search(r'\b(charniak-parser)\b', str)
    if a is None:
        return False
    else:
        return True
def ispytextrank(str):
    a = re.search(r'\b(pytextrank)\b', str)
    if a is None:
        return False
    else:
        return True
def istransformers(str):
    a = re.search(r'\b(huggingface-transformers)\b', str)
    if a is None:
        return False
    else:
        return True
def israsanlu(str):
    a = re.search(r'\b(rasa-nlu)\b', str)
    if a is None:
        return False
    else:
        return True
def isdialogflowes(str):
    a = re.search(r'\b(dialogflow-es)\b', str)
    if a is None:
        return False
    else:
        return True
def istokenizers(str):
    a = re.search(r'\b(huggingface-tokenizers)\b', str)
    if a is None:
        return False
    else:
        return True
def isjohnsnowlabs(str):
    a = re.search(r'\b(johnsnowlabs-spark-nlp)\b', str)
    if a is None:
        return False
    else:
        return True
def isflair(str):
    a = re.search(r'\b(flair)\b', str)
    if a is None:
        return False
    else:
        return True
def issense2vec(str):
    a = re.search(r'\b(sense2vec)\b', str)
    if a is None:
        return False
    else:
        return True
def ispattern(str):
    a = re.search(r'\b(python-pattern)\b', str)
    if a is None:
        return False
    else:
        return True

# %%
for index, row in df.iterrows():
    title = str(row['Title'])
    tags = str(row['Tags'])
    body = str(row['Body'])
    df.at[index, 'nltk'] = isnltk(tags)
    df.at[index, 'spacy'] = isspacy(tags)
    df.at[index, 'gensim'] = isgensim(tags)
    df.at[index, 'stanford-nlp'] = isstanfordnlp(tags)
    df.at[index, 'scikit-learn'] = issklearn(tags)
    df.at[index, 'textblob'] = istextblob(tags)
    df.at[index, 'polyglot'] = ispolyglot(tags)
    df.at[index, 'opennlp'] = isopennlp(tags)
    df.at[index, 'charniak-parser'] = ischarniakparser(tags)
    df.at[index, 'pytextrank'] = ispytextrank(tags)
    df.at[index, 'huggingface-transformers'] = istransformers(tags)
    df.at[index, 'rasa-nlu'] = israsanlu(tags)
    df.at[index, 'dialogflow-es'] = isdialogflowes(tags)
    df.at[index, 'huggingface-tokenizers'] = istokenizers(tags)
    df.at[index, 'johnsnowlabs-spark-nlp'] = isjohnsnowlabs(tags)
    df.at[index, 'flair'] = isflair(tags)
    df.at[index, 'sense2vec'] = issense2vec(tags)
    df.at[index, 'python-pattern'] = ispattern(tags)

nltk = df[df['nltk'] == True]
spacy = df[df['spacy'] == True]
gensim = df[df['gensim'] == True]
stanfordnlp = df[df['stanford-nlp'] == True]
sklearn = df[df['scikit-learn'] == True]
textblob = df[df['textblob'] == True]
polyglot = df[df['polyglot'] == True]
opennlp = df[df['opennlp'] == True]
charniakparser = df[df['charniak-parser'] == True]
pytextrank = df[df['pytextrank'] == True]
transformers = df[df['huggingface-transformers'] == True]
rasanlu = df[df['rasa-nlu'] == True]
dialogflow = df[df['dialogflow-es'] == True]
tokenizers = df[df['huggingface-tokenizers'] == True]
johnsonwlabs = df[df['johnsnowlabs-spark-nlp'] == True]
flair = df[df['flair'] == True]
sense2vec = df[df['sense2vec'] == True]
pattern = df[df['python-pattern'] == True]
